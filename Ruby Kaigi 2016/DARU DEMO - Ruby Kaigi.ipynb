# %% [markdown]
# # Ruby Kaigi 2016, Kyoto
#
# # Basic demonstration of daru

# %% [markdown]
# # daru (Data Analysis in RUby)

# %% [markdown]
# ## daru is a Ruby gem for analysis, manipulation and cleaning of data. It works well with all the above gems and makes it very easy to perform complex data analysis, cleaning and visualization tasks.

# %%
require 'daru'
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\n\t};\n\n\n});});\n}\n"
# true

# %% [markdown]
# ## A simple case of `Daru::Vector`

# %%
vec = Daru::Vector.new([1,2,3,4,5])
# Out:
# #<Daru::Vector(5)>
#    0   1
#    1   2
#    2   3
#    3   4
#    4   5

# %% [markdown]
# ## Initializing a Vector with a `Daru::Index`

# %%
index = Daru::Index.new(['ichi','ni','san','shi','go','roku'])
vec = Daru::Vector.new([1,2,3,4,5,6], index: index)
# Out:
# #<Daru::Vector(6)>
#  ichi    1
#    ni    2
#   san    3
#   shi    4
#    go    5
#  roku    6

# %% [markdown]
# ### Select an element by index

# %%
vec['san']
# Out:
# 3

# %% [markdown]
# ### Select multiple elements by index

# %%
vec['ichi', 'go']
# Out:
# #<Daru::Vector(2)>
#  ichi    1
#    go    5

# %% [markdown]
# ### Select a Range of elements

# %%
vec['san'..'go']
# Out:
# #<Daru::Vector(3)>
#  san   3
#  shi   4
#   go   5

# %% [markdown]
# ## A simple case of Daru::DataFrame

# %%
df = Daru::DataFrame.new({
  a: [1342,223,3422,4234,5332],
  b: 'a'..'e',
  c: Array.new(5) {|i| i},
  d: ['Junmai-shu', 'Honjozo-shu', 'Ginjo-shu', 'Daiginjo-shu', 'Namazake']
  })
df
# Out:
# #<Daru::DataFrame(5x4)>
#                      a          b          c          d
#           0       1342          a          0 Junmai-shu
#           1        223          b          1 Honjozo-sh
#           2       3422          c          2  Ginjo-shu
#           3       4234          d          3 Daiginjo-s
#           4       5332          e          4   Namazake

# %% [markdown]
# ### Select a single column with the `#[]` operator

# %%
df[:b]
# Out:
# #<Daru::Vector(5)>
#        b
#    0   a
#    1   b
#    2   c
#    3   d
#    4   e

# %% [markdown]
# ### Select multiple columns by specifying a Range

# %%
df[:b..:d]
# Out:
# #<Daru::DataFrame(5x3)>
#                      b          c          d
#           0          a          0 Junmai-shu
#           1          b          1 Honjozo-sh
#           2          c          2  Ginjo-shu
#           3          d          3 Daiginjo-s
#           4          e          4   Namazake

# %% [markdown]
# ### Or separate by commas

# %%
df[:a, :c]
# Out:
# #<Daru::DataFrame(5x2)>
#          a    c
#     0 1342    0
#     1  223    1
#     2 3422    2
#     3 4234    3
#     4 5332    4

# %% [markdown]
# ### Rows can be accessed with the `#row[]` method.

# %%
df.row[3]
# Out:
# #<Daru::Vector(4)>
#                          3
#             a         4234
#             b            d
#             c            3
#             d Daiginjo-shu

# %% [markdown]
# ### It also supports multiple retrieval with Range or commas

# %%
df.row[1..4]
# Out:
# #<Daru::DataFrame(4x4)>
#                      a          b          c          d
#           1        223          b          1 Honjozo-sh
#           2       3422          c          2  Ginjo-shu
#           3       4234          d          3 Daiginjo-s
#           4       5332          e          4   Namazake

# %% [markdown]
# ### The default alphabetical ordering of columns can be changed with the `:order` option.

# %%
data_frame = Daru::DataFrame.new({
  a: [1,2,3,4,5],
  b: 'a'..'e',
  c: Array.new(5) {|i| i},
  d: ['Junmai-shu', 'Honjozo-shu', 'Ginjo-shu', 'Daiginjo-shu', 'Namazake']
  }, order: [:b, :d, :c, :a])
# Out:
# #<Daru::DataFrame(5x4)>
#                      b          d          c          a
#           0          a Junmai-shu          0          1
#           1          b Honjozo-sh          1          2
#           2          c  Ginjo-shu          2          3
#           3          d Daiginjo-s          3          4
#           4          e   Namazake          4          5

# %% [markdown]
# ### You can also specify a row index with the `:index` option

# %%
data_frame = Daru::DataFrame.new({
  a: [1,2,3,4,5],
  b: 'a'..'e',
  c: Array.new(5) {|i| i},
  d: ['Junmai-shu', 'Honjozo-shu', 'Ginjo-shu', 'Daiginjo-shu', 'Namazake']
  }, order: [:b, :d, :c, :a], index: ['ichi','ni','san','shi','go'])
# Out:
# #<Daru::DataFrame(5x4)>
#                      b          d          c          a
#        ichi          a Junmai-shu          0          1
#          ni          b Honjozo-sh          1          2
#         san          c  Ginjo-shu          2          3
#         shi          d Daiginjo-s          3          4
#          go          e   Namazake          4          5

# %% [markdown]
# DataFrame has powerful indexing capabilities:
#
# * `Daru::Index`
# * `Daru::MultiIndex`
# * `Daru::DateTimeIndex`
# * `Daru::CategoricalIndex`

# %% [markdown]
# ## A MultiIndex is a hierarchical index

# %%
multi_index = Daru::MultiIndex.from_tuples([
  [:a, :b, :c],
  [:a, :b, :d],
  [:a, :b, :p],
  [:a, :q, :p],
  [:b, :r, :f],
  [:c, :o, :t],
  [:c, :p, :w]
  ])
# Out:
# #<Daru::MultiIndex(7x3)>
#    a   b   c
#            d
#            p
#        q   p
#    b   r   f
#    c   o   t
#        p   w

# %% [markdown]
# ### It allows you create and query hierarchically named data

# %%
vec = Daru::Vector.new([1,2,3]*2 << 66, index: multi_index)
# Out:
# #<Daru::Vector(7)>
#    a   b   c   1
#            d   2
#            p   3
#        q   p   1
#    b   r   f   2
#    c   o   t   3
#        p   w  66

# %% [markdown]
# ### You can select data by specifying the hierarchy in the #[] method.

# %%
vec[:a, :b, :p]
# Out:
# 3

# %% [markdown]
# ### Specifying an incomplete hierarchical index will return data under that index.

# %%
vec[:a]
# Out:
# #<Daru::Vector(4)>
#    b   c   1
#        d   2
#        p   3
#    q   p   1

# %% [markdown]
# ## The DateTimeIndex allows you to index timestamp-based data like stock prices

# %% [markdown]
# ## Create a `Daru::DateTimeIndex` with a frequency of 3 minutes.

# %%
date_time = Daru::DateTimeIndex.date_range(start: '2011', end: '2011-3', freq: '3M')
# Out:
# #<Daru::DateTimeIndex(28321, frequency=3M) 2011-01-01T00:00:00+00:00...2011-03-01T00:00:00+00:00>

# %%
vec = Daru::Vector.new([15]*date_time.size, index: date_time)
vec.head
# Out:
# #<Daru::Vector(10)>
#  2011-01-01T00:00:00+                   15
#  2011-01-01T00:03:00+                   15
#  2011-01-01T00:06:00+                   15
#  2011-01-01T00:09:00+                   15
#  2011-01-01T00:12:00+                   15
#  2011-01-01T00:15:00+                   15
#  2011-01-01T00:18:00+                   15
#  2011-01-01T00:21:00+                   15
#  2011-01-01T00:24:00+                   15
#  2011-01-01T00:27:00+                   15

# %% [markdown]
# ### Query data based on a date range.

# %%
vec['2011-1'..'2011-2-10']
# Out:
# #<Daru::Vector(19680)>
#  2011-01-01T00:00:00+                   15
#  2011-01-01T00:03:00+                   15
#  2011-01-01T00:06:00+                   15
#  2011-01-01T00:09:00+                   15
#  2011-01-01T00:12:00+                   15
#  2011-01-01T00:15:00+                   15
#  2011-01-01T00:18:00+                   15
#  2011-01-01T00:21:00+                   15
#  2011-01-01T00:24:00+                   15
#  2011-01-01T00:27:00+                   15
#  2011-01-01T00:30:00+                   15
#  2011-01-01T00:33:00+                   15
#  2011-01-01T00:36:00+                   15
#  2011-01-01T00:39:00+                   15
#  2011-01-01T00:42:00+                   15
#                   ...                  ...

# %% [markdown]
# ### Get the data for a specific day.

# %%
vec['2011-1-21']
# Out:
# #<Daru::Vector(480)>
#  2011-01-21T00:00:00+                   15
#  2011-01-21T00:03:00+                   15
#  2011-01-21T00:06:00+                   15
#  2011-01-21T00:09:00+                   15
#  2011-01-21T00:12:00+                   15
#  2011-01-21T00:15:00+                   15
#  2011-01-21T00:18:00+                   15
#  2011-01-21T00:21:00+                   15
#  2011-01-21T00:24:00+                   15
#  2011-01-21T00:27:00+                   15
#  2011-01-21T00:30:00+                   15
#  2011-01-21T00:33:00+                   15
#  2011-01-21T00:36:00+                   15
#  2011-01-21T00:39:00+                   15
#  2011-01-21T00:42:00+                   15
#                   ...                  ...

# %% [markdown]
# ## A `Daru::CategoricalIndex` can be used if data is purely categorical.

# %%
require 'open-uri'
# Out:
# true

# %%
content = open('https://d37djvu3ytnwxt.cloudfront.net/asset-v1:MITx+15.071x_3+1T2016+type@asset+block/WHO.csv')
df = Daru::DataFrame.from_csv content
df[0..5]
# Out:
# #<Daru::DataFrame(194x6)>
#                Country     Region Population    Under15     Over60 FertilityR
#           0 Afghanista Eastern Me      29825      47.42       3.82        5.4
#           1    Albania     Europe       3162      21.33      14.93       1.75
#           2    Algeria     Africa      38482      27.42       7.17       2.83
#           3    Andorra     Europe         78       15.2      22.86        nil
#           4     Angola     Africa      20821      47.58       3.84        6.1
#           5 Antigua an   Americas         89      25.96      12.35       2.12
#           6  Argentina   Americas      41087      24.42      14.97        2.2
#           7    Armenia     Europe       2969      20.34      14.06       1.74
#           8  Australia Western Pa      23050      18.95      19.46       1.89
#           9    Austria     Europe       8464      14.51      23.52       1.44
#          10 Azerbaijan     Europe       9309      22.25       8.24       1.96
#          11    Bahamas   Americas        372      21.62      11.24        1.9
#          12    Bahrain Eastern Me       1318      20.16       3.38       2.12
#          13 Bangladesh South-East     155000      30.57       6.89       2.24
#          14   Barbados   Americas        283      18.99      15.78       1.84
#         ...        ...        ...        ...        ...        ...        ...

# %% [markdown]
# ### Setting the Index of the dataframe to a Categorical Index.

# %%
df.index = Daru::CategoricalIndex.new (df['Region']).to_a
# Out:
# #<Daru::CategoricalIndex(194): {Eastern Mediterranean, Europe, Africa, Europe, Africa, Americas, Americas, Europe, Western Pacific, Europe, Europe, Americas, Eastern Mediterranean, South-East Asia, Americas, Europe, Europe, Americas, Africa, South-East Asia ... Africa}>

# %% [markdown]
# ### To see all the categories of Regions use `#categories`.

# %%
df.index.categories
df
# Out:
# #<Daru::DataFrame(194x13)>
#                Country     Region Population    Under15     Over60 FertilityR LifeExpect ChildMorta CellularSu LiteracyRa        GNI PrimarySch PrimarySch
#  Eastern Me Afghanista Eastern Me      29825      47.42       3.82        5.4         60       98.5      54.26        nil       1140        nil        nil
#      Europe    Albania     Europe       3162      21.33      14.93       1.75         74       16.7      96.39        nil       8820        nil        nil
#      Africa    Algeria     Africa      38482      27.42       7.17       2.83         73         20      98.99        nil       8310       98.2       96.4
#      Europe    Andorra     Europe         78       15.2      22.86        nil         82        3.2      75.49        nil        nil       78.4       79.4
#      Africa     Angola     Africa      20821      47.58       3.84        6.1         51      163.5      48.38       70.1       5230       93.1       78.2
#    Americas Antigua an   Americas         89      25.96      12.35       2.12         75        9.9     196.41       99.0      17900       91.1       84.5
#    Americas  Argentina   Americas      41087      24.42      14.97        2.2         76       14.2     134.92       97.8      17130        nil        nil
#      Europe    Armenia     Europe       2969      20.34      14.06       1.74         71       16.4     103.57       99.6       6100        nil        nil
#  Western Pa  Australia Western Pa      23050      18.95      19.46       1.89         82        4.9     108.34        nil      38110       96.9       97.5
#      Europe    Austria     Europe       8464      14.51      23.52       1.44         81          4     154.78        nil      42050        nil        nil
#      Europe Azerbaijan     Europe       9309      22.25       8.24       1.96         71       35.2     108.75        nil       8960       85.3       84.1
#    Americas    Bahamas   Americas        372      21.62      11.24        1.9         75       16.9      86.06        nil        nil        nil        nil
#  Eastern Me    Bahrain Eastern Me       1318      20.16       3.38       2.12         79        9.6     127.96       91.9        nil        nil        nil
#  South-East Bangladesh South-East     155000      30.57       6.89       2.24         70       40.9      56.06       56.8       1940        nil        nil
#    Americas   Barbados   Americas        283      18.99      15.78       1.84         78       18.4     127.01        nil        nil        nil        nil
#         ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...

# %% [markdown]
# ### Let's see how many countries lie in the 'Africa' region.

# %%
df.row['Africa'].size
# Out:
# 46

# %% [markdown]
# ### To get mean value of the Life Expectancy in Europe:

# %%
df.row['Europe']['LifeExpectancy'].mean
# Out:
# 76.73584905660377

# %% [markdown]
# # Data Querying
#
# ## Data can be queried with a Arel-like querying syntax

# %%
df = Daru::DataFrame.new({
  'Country' => ['Japan','India', 'USA', 'Canada', 'Germany', 'Russia', 'China','Cuba'],
  'Beverage' => ['Sake', 'Toddy', 'Beer', 'Beer', 'Beer', 'Vodka', 'Beer' , 'Rum'],
  'Drinking Population (%)' => [75, 50, 43, 60, 80, 70, 54, 90]
  })
# Out:
# #<Daru::DataFrame(8x3)>
#               Beverage    Country Drinking P
#           0       Sake      Japan         75
#           1      Toddy      India         50
#           2       Beer        USA         43
#           3       Beer     Canada         60
#           4       Beer    Germany         80
#           5      Vodka     Russia         70
#           6       Beer      China         54
#           7        Rum       Cuba         90

# %% [markdown]
# ## It supports all logical operations on data.

# %%
df.where(df['Beverage'].eq('Beer'))
# Out:
# #<Daru::DataFrame(4x3)>
#               Beverage    Country Drinking P
#           2       Beer        USA         43
#           3       Beer     Canada         60
#           4       Beer    Germany         80
#           6       Beer      China         54

# %% [markdown]
# ## Conditions can be clubbed together with `&` (AND) and `|` (OR) operators.

# %%
df.where(df['Beverage'].eq('Beer') | df['Drinking Population (%)'].lt(70))
# Out:
# #<Daru::DataFrame(5x3)>
#               Beverage    Country Drinking P
#           1      Toddy      India         50
#           2       Beer        USA         43
#           3       Beer     Canada         60
#           4       Beer    Germany         80
#           6       Beer      China         54

# %% [markdown]
# # Basic Operations on Data

# %% [markdown]
# ## Sorting
#
# ### Sorting can be done with `DataFrame#sort`. It supports missing data in the Vector(s).

# %%
df['Drinking Population (%)'] = [75, 50, nil, 60, nil, 70, 54, nil]
# Out:
# [75, 50, nil, 60, nil, 70, 54, nil]

# %%
df.sort(['Drinking Population (%)'])
# Out:
# #<Daru::DataFrame(8x3)>
#               Beverage    Country Drinking P
#           2       Beer        USA        nil
#           4       Beer    Germany        nil
#           7        Rum       Cuba        nil
#           1      Toddy      India         50
#           6       Beer      China         54
#           3       Beer     Canada         60
#           5      Vodka     Russia         70
#           0       Sake      Japan         75

# %%
df.sort(['Drinking Population (%)', 'Beverage'], ascending: false)
# Out:
# #<Daru::DataFrame(8x3)>
#               Beverage    Country Drinking P
#           7        Rum       Cuba        nil
#           2       Beer        USA        nil
#           4       Beer    Germany        nil
#           0       Sake      Japan         75
#           5      Vodka     Russia         70
#           3       Beer     Canada         60
#           6       Beer      China         54
#           1      Toddy      India         50

# %% [markdown]
# ## Basic statistics
#
# ### Various methods let you perform statistics on vectors even when missing data is present.

# %%
df.mean
# Out:
# #<Daru::Vector(1)>
#                                       mean
#  Drinking Population                  61.8

# %%
df.describe
# Out:
# #<Daru::DataFrame(5x1)>
#             Drinking P
#       count          5
#        mean       61.8
#         std 10.5451410
#         min         50
#         max         75

# %% [markdown]
# ## Filtering
#
# ### `DataFrame#filter_rows` allows filtering rows based on certain conditions.

# %%
df.filter_rows do |row|
  !row['Country'].nil? && row['Country'] == 'Japan' || ['Beer', 'Vodka'].include?(row['Beverage'])
end
# Out:
# #<Daru::DataFrame(6x3)>
#               Beverage    Country Drinking P
#           0       Sake      Japan         75
#           2       Beer        USA        nil
#           3       Beer     Canada         60
#           4       Beer    Germany        nil
#           5      Vodka     Russia         70
#           6       Beer      China         54

# %% [markdown]
# ### `DataFrame#recode_rows` allows changing rows based on certain conditions.

# %%
df.recode_rows do |row|
  if !row['Drinking Population (%)'].nil? && row['Drinking Population (%)'] < 60
    row['Beverage'] = "Mild #{row['Beverage']}"
  end
  
  row
end
# Out:
# #<Daru::DataFrame(8x3)>
#               Beverage    Country Drinking P
#           0       Sake      Japan         75
#           1 Mild Toddy      India         50
#           2       Beer        USA        nil
#           3       Beer     Canada         60
#           4       Beer    Germany        nil
#           5      Vodka     Russia         70
#           6  Mild Beer      China         54
#           7        Rum       Cuba        nil

# %% [markdown]
# ## Joining
#
# ### SQL-style joins can be performed with the `DataFrame#join` method.

# %%
left = Daru::DataFrame.new({
  :id   => [1,2,3,4],
  :name => ['Pirate', 'Monkey', 'Ninja', 'Spaghetti']
})
right = Daru::DataFrame.new({
  :id => [1,2,3,4],
  :name => ['Rutabaga', 'Pirate', 'Darth Vader', 'Ninja']
})

left.join(right, on: [:name], how: :inner)
# Out:
# #<Daru::DataFrame(2x3)>
#           id_1   name   id_2
#       0      3  Ninja      4
#       1      1 Pirate      2

# %% [markdown]
# ## Aggregation with group_by

# %%
df = Daru::DataFrame.new({
  a: %w{foo bar foo bar   foo bar foo foo},
  b: %w{one one two three two two one three},
  c:   [1  ,2  ,3  ,1    ,3  ,6  ,3  ,8],
  d:   [11 ,22 ,33 ,44   ,55 ,66 ,77 ,88]
})
# Out:
# #<Daru::DataFrame(8x4)>
#            a     b     c     d
#      0   foo   one     1    11
#      1   bar   one     2    22
#      2   foo   two     3    33
#      3   bar three     1    44
#      4   foo   two     3    55
#      5   bar   two     6    66
#      6   foo   one     3    77
#      7   foo three     8    88

# %%
groups = df.group_by [:a, :b]
groups.groups
# Out:
# {["bar", "one"]=>[1], ["bar", "three"]=>[3], ["bar", "two"]=>[5], ["foo", "one"]=>[0, 6], ["foo", "three"]=>[7], ["foo", "two"]=>[2, 4]}

# %% [markdown]
# ### The `GroupBy#first` method will show the first rows of each group.

# %%
groups.first
# Out:
# #<Daru::DataFrame(6x4)>
#            a     b     c     d
#      1   bar   one     2    22
#      3   bar three     1    44
#      5   bar   two     6    66
#      0   foo   one     1    11
#      7   foo three     8    88
#      2   foo   two     3    33

# %% [markdown]
# ### Obtain a summary of the grouped data with `#mean`.

# %%
groups.mean
# Out:
# #<Daru::DataFrame(6x2)>
#                  c     d
#    bar   one     2    22
#        three     1    44
#          two     6    66
#    foo   one   2.0  44.0
#        three     8    88
#          two   3.0  44.0

# %% [markdown]
# ## Visualization
#
# ### Daru can be used with nyaplot for generating interactive graphs.

# %%
df = Daru::DataFrame.new({
  :temperature => [30.4, 23.5, 44.5, 20.3, 34, 24, 31.45, 28.34, 37, 24],
  :sales       => [350, 150, 500, 200, 480, 250, 330, 400, 420, 560],
  :city        => ['Pune', 'Delhi']*5,
  :staff       => [15,20]*5
})
df
# Out:
# #<Daru::DataFrame(10x4)>
#                   city      sales      staff temperatur
#           0       Pune        350         15       30.4
#           1      Delhi        150         20       23.5
#           2       Pune        500         15       44.5
#           3      Delhi        200         20       20.3
#           4       Pune        480         15         34
#           5      Delhi        250         20         24
#           6       Pune        330         15      31.45
#           7      Delhi        400         20      28.34
#           8       Pune        420         15         37
#           9      Delhi        560         20         24

# %% [markdown]
# ### Plotting the temperature of the city vs. the sales of ice cream.

# %%
df.plot(type: :scatter, x: :temperature, y: :sales) do |plot, diagram|
  plot.x_label "Temperature"
  plot.y_label "Sales"
  plot.yrange [100, 600]
  plot.xrange [15, 50]
  diagram.tooltip_contents([:city, :staff])
  # Set the color scheme for this diagram.
  diagram.color(Nyaplot::Colors.qual) 
  # Change color of each point WRT to the city that it belongs to.
  diagram.fill_by(:city)
  # Shape each point WRT to the city that it belongs to.
  diagram.shape_by(:city) 
end
# Out:
# #<Nyaplot::Frame:0xb3aa600 @properties={:panes=>[#<Nyaplot::Plot:0xb3a3b48 @properties={:diagrams=>[#<Nyaplot::Diagram:0xb3aad08 @properties={:type=>:scatter, :options=>{:x=>:temperature, :y=>:sales, :tooltip_contents=>[:city, :staff], :color=>#<Nyaplot::Color:0xb3aa664 @source=["rgb(141,211,199)", "rgb(255,255,179)", "rgb(190,186,218)", "rgb(251,128,114)", "rgb(128,177,211)", "rgb(253,180,98)", "rgb(179,222,105)", "rgb(252,205,229)", "rgb(217,217,217)"]>, :fill_by=>:city, :shape_by=>:city}, :data=>"1e609a03-9578-4102-8a97-30200f562f0f"}, @xrange=[20.3, 44.5], @yrange=[150, 560]>], :options=>{:x_label=>"Temperature", :y_label=>"Sales", :yrange=>[100, 600], :xrange=>[15, 50], :zoom=>true, :width=>700}}>], :data=>{"1e609a03-9578-4102-8a97-30200f562f0f"=>#<Nyaplot::DataFrame:0xb3ab0f0 @name="1e609a03-9578-4102-8a97-30200f562f0f", @rows=[{:city=>"Pune", :sales=>350, :staff=>15, :temperature=>30.4}, {:city=>"Delhi", :sales=>150, :staff=>20, :temperature=>23.5}, {:city=>"Pune", :sales=>500, :staff=>15, :temperature=>44.5}, {:city=>"Delhi", :sales=>200, :staff=>20, :temperature=>20.3}, {:city=>"Pune", :sales=>480, :staff=>15, :temperature=>34}, {:city=>"Delhi", :sales=>250, :staff=>20, :temperature=>24}, {:city=>"Pune", :sales=>330, :staff=>15, :temperature=>31.45}, {:city=>"Delhi", :sales=>400, :staff=>20, :temperature=>28.34}, {:city=>"Pune", :sales=>420, :staff=>15, :temperature=>37}, {:city=>"Delhi", :sales=>560, :staff=>20, :temperature=>24}]>}, :extension=>[]}>
