# %% [markdown]
# # Introduction to daru (Data Analysis in RUby)
#
# ## Sameer Deshmukh
#
# ### Srijan Webinar, 29th June 2016.

# %%
require 'daru'
require 'distribution'
require 'gnuplotrb'
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min\",\"downloadable\":\"http://cdn.rawgit.com/domitry/d3-downloadable/master/d3-downloadable\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"downloadable\":{\"exports\":\"downloadable\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');require(['downloadable'], function(downloadable){window['downloadable']=downloadable;console.log('finished loading downloadable');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"http://cdn.rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\n\t};\n\n\n});});\n}\n"
# true

# %% [markdown]
# ### Creating a Daru::Vector
#
# **Vectors are indexed by passing data using the `index` option, and named with `name`**

# %%
vector = Daru::Vector.new(
  [20,40,25,50,45,12], index: ['cherry', 'apple', 'barley', 'wheat', 'rice', 'sugar'], 
  name: "Prices of stuff.")
# Out:
# #<Daru::Vector(6)>
#                   Prices of stuff.
#            cherry               20
#             apple               40
#            barley               25
#             wheat               50
#              rice               45
#             sugar               12

# %% [markdown]
# ### Retreive a single value
#
# **Specify the index you want to retrieve in the `#[]` operator**

# %%
vector['rice']
# Out:
# 45

# %% [markdown]
# ### Retreive multiple values
#
# **Multiple values can be retreived at the same time as another Daru::Vector by separating them with commas.**

# %%
vector['rice', 'wheat', 'sugar']
# Out:
# #<Daru::Vector(3)>
#                   Prices of stuff.
#              rice               45
#             wheat               50
#             sugar               12

# %% [markdown]
# ### Retreive a slice with a Range
#
# **Specifying a range of indexes will retrieve a slice of the Daru::Vector**

# %%
vector['barley'..'sugar']
# Out:
# #<Daru::Vector(4)>
#                   Prices of stuff.
#            barley               25
#             wheat               50
#              rice               45
#             sugar               12

# %% [markdown]
# ### Assign a value
#
# **Assign a value by specifying the index directly to the #[]= operator**

# %%
vector['barley'] = 1500
vector
# Out:
# #<Daru::Vector(6)>
#                   Prices of stuff.
#            cherry               20
#             apple               40
#            barley             1500
#             wheat               50
#              rice               45
#             sugar               12

# %% [markdown]
# ### Creating a Daru::DataFrame
#
# **The `:index` option is used for specifying the row index of the DataFrame and the `:order` option determines the order in which they will be stored.**
#
# **Note that this is only one way of creating a DataFrame. There are around 8 different ways you can do so, depending on your use case.**

# %%
df = Daru::DataFrame.new({
  'col0' => [1,2,3,4,5,6],
  'col2' => ['a','b','c','d','e','f'],
  'col1' => [11,22,33,44,55,66]
  }, 
  index: ['one', 'two', 'three', 'four', 'five', 'six'], 
  order: ['col0', 'col1', 'col2']
  )
# Out:
# #<Daru::DataFrame(6x3)>
#         col0  col1  col2
#    one     1    11     a
#    two     2    22     b
#  three     3    33     c
#   four     4    44     d
#   five     5    55     e
#    six     6    66     f

# %% [markdown]
# ### Accessing a Column
#
# **A DataFrame column can be accessed using the DataFrame#[] operator.**
#
# **Note that it returns a Daru::Vector**

# %%
df['col1']
# Out:
# #<Daru::Vector(6)>
#         col1
#    one    11
#    two    22
#  three    33
#   four    44
#   five    55
#    six    66

# %% [markdown]
# ### Accessing multiple Columns
#
# **Multiple columns can be accessed by separating them with a comma. The result is another DataFrame.**

# %%
df['col2', 'col0']
# Out:
# #<Daru::DataFrame(6x2)>
#         col2  col0
#    one     a     1
#    two     b     2
#  three     c     3
#   four     d     4
#   five     e     5
#    six     f     6

# %% [markdown]
# ### Accessing a Range of Columns
#
# **A slice of the DataFrame by columns can be obtained by specifying a Range in #[]**

# %%
df['col1'..'col2']
# Out:
# #<Daru::DataFrame(6x2)>
#         col1  col2
#    one    11     a
#    two    22     b
#  three    33     c
#   four    44     d
#   five    55     e
#    six    66     f

# %% [markdown]
# ### Assigning a Column
#
# **You can assign a Daru::Vector to a column and the indexes of the Vector will be automatically matched to that of the DataFrame.**

# %%
df['col1'] = Daru::Vector.new(['this', 'is', 'some','new','data','here'], 
  index: ['one', 'three','two','six','four', 'five'])
df
# Out:
# #<Daru::DataFrame(6x3)>
#         col0  col1  col2
#    one     1  this     a
#    two     2  some     b
#  three     3    is     c
#   four     4  data     d
#   five     5  here     e
#    six     6   new     f

# %% [markdown]
# ### Accessing a Row
#
# **A single row can be accessed using the `#row[]` function.**

# %%
df.row['four']
# Out:
# #<Daru::Vector(3)>
#       four
#  col0    4
#  col1 data
#  col2    d

# %% [markdown]
# ### Accessing a Range of Rows
#
# **Specifying a Range of Row indexes in `#row[]` will select a DataFrame with those rows**

# %%
df.row['three'..'five']
# Out:
# #<Daru::DataFrame(3x3)>
#         col0  col1  col2
#  three     3    is     c
#   four     4  data     d
#   five     5  here     e

# %% [markdown]
# ### Assigning a Row
#
# **You can also assign a Row with Daru::Vector. Notice that indexes are mathced according to the order of the DataFrame.**

# %%
df.row['five'] = [666,555,333]
# Out:
# [666, 555, 333]

# %% [markdown]
# ### Statistics on Vector with missing data
#
# **A host of static and rolling statistics methods are provided on Daru::Vector.**
#
# **Note that missing data (very common in most real world scenarios) is gracefully handled**

# %%
vector = Daru::Vector.new([1,3,5,nil,2,53,nil])
vector.mean
# Out:
# 12.8

# %% [markdown]
# ### Statistics on DataFrame
#
# **DataFrame statistics will basically apply the concerned method on all numerical columns of the DataFrame.**

# %%
df.mean
# Out:
# #<Daru::Vector(1)>
#                                   mean
#                col0 113.66666666666667

# %% [markdown]
# **Useful statistics about the vectors in a DataFrame can be observed with `#describe`**

# %%
df.describe
# Out:
# #<Daru::DataFrame(5x1)>
#                   col0
#       count          6
#        mean 113.666666
#         std 270.592436
#         min          1
#         max        666

# %% [markdown]
# ## Time Series Support
#
# **Daru offers a robust time series manipulation API for indexing data based on timestamps. This makes daru a viable tool for analyzing financial data (or any data that changes with time)**

# %% [markdown]
# ### The DateTimeIndex
#
# **The DateTimeIndex is a special index for indexing data based on timestamps.**
#
# **A date index range can be created using the DateTimeIndex.date_range function. The `:freq` option decides the time frequency between each timestamp in the date index.**

# %%
index = Daru::DateTimeIndex.date_range(:start => '2012', :periods => 1000, :freq => '3D')
# Out:
# #<Daru::DateTimeIndex(1000, frequency=3D) 2012-01-01T00:00:00+00:00...2020-03-16T00:00:00+00:00>

# %% [markdown]
# **A Daru::Vector can be created by simply passing the newly created index object into the `:index` argument.**

# %%
timeseries = Daru::Vector.new(1000.times.map {rand}, index: index)
# Out:
# #<Daru::Vector(1000)>
#  2012-01-01T00:00:00+  0.02216856402288081
#  2012-01-04T00:00:00+  0.48422866990952773
#  2012-01-07T00:00:00+   0.7299340250251456
#  2012-01-10T00:00:00+   0.7875525212897787
#  2012-01-13T00:00:00+   0.5826141862466429
#  2012-01-16T00:00:00+   0.6616943639788442
#  2012-01-19T00:00:00+   0.3517854180035117
#  2012-01-22T00:00:00+   0.5995398759031499
#  2012-01-25T00:00:00+   0.6911971357406449
#  2012-01-28T00:00:00+   0.7484925626291649
#  2012-01-31T00:00:00+   0.8686603561380941
#  2012-02-03T00:00:00+  0.17796512658491526
#  2012-02-06T00:00:00+   0.6511954930795819
#  2012-02-09T00:00:00+  0.27645094283155325
#  2012-02-12T00:00:00+  0.16588558778424967
#                   ...                  ...

# %% [markdown]
# ### Accessing data by partial timestamps
#
# **When a Vector or DataFrame is indexed by a DateTimeIndex, it allows you to partially specify the date to retreive all the data that belongs to that date.**
#
# **For example, to access all the data belonging to the year 2012.**

# %%
timeseries['2012']
# Out:
# #<Daru::Vector(122)>
#  2012-01-01T00:00:00+  0.02216856402288081
#  2012-01-04T00:00:00+  0.48422866990952773
#  2012-01-07T00:00:00+   0.7299340250251456
#  2012-01-10T00:00:00+   0.7875525212897787
#  2012-01-13T00:00:00+   0.5826141862466429
#  2012-01-16T00:00:00+   0.6616943639788442
#  2012-01-19T00:00:00+   0.3517854180035117
#  2012-01-22T00:00:00+   0.5995398759031499
#  2012-01-25T00:00:00+   0.6911971357406449
#  2012-01-28T00:00:00+   0.7484925626291649
#  2012-01-31T00:00:00+   0.8686603561380941
#  2012-02-03T00:00:00+  0.17796512658491526
#  2012-02-06T00:00:00+   0.6511954930795819
#  2012-02-09T00:00:00+  0.27645094283155325
#  2012-02-12T00:00:00+  0.16588558778424967
#                   ...                  ...

# %% [markdown]
# **Or to access data whose time stamp is March 2012...**

# %%
timeseries['2012-3']
# Out:
# #<Daru::Vector(11)>
#  2012-03-01T00:00:00+   0.3449493099859111
#  2012-03-04T00:00:00+   0.8884204461039671
#  2012-03-07T00:00:00+  0.27801869918559874
#  2012-03-10T00:00:00+  0.10227866959845877
#  2012-03-13T00:00:00+   0.1981534962725574
#  2012-03-16T00:00:00+  0.35453776756179556
#  2012-03-19T00:00:00+   0.5692080686650818
#  2012-03-22T00:00:00+   0.8040248900146737
#  2012-03-25T00:00:00+   0.2315930955003509
#  2012-03-28T00:00:00+  0.26216555673444286
#  2012-03-31T00:00:00+   0.8914301701096374

# %% [markdown]
# **Specifying the date precisely will return the exact data point (You can also pass a ruby DateTime object for precisely obtaining data).**

# %%
timeseries['2012-3-10']
# Out:
# 0.10227866959845877

# %% [markdown]
# **Say you have per second data about the price of a commodity and want to access the prices for the minute on 23rd of March 2012 at 12:42 pm**

# %%
index      = Daru::DateTimeIndex.date_range(
  :start => '2012-3-23 11:00', :periods => 20000, :freq => 'S')

seconds_ts = Daru::Vector.new(20000.times.map { rand(50) }, index: index)
seconds_ts['2012-3-23 12:42']
# Out:
# #<Daru::Vector(60)>
#  2012-03-23T12:42:00+                   34
#  2012-03-23T12:42:01+                   35
#  2012-03-23T12:42:02+                   45
#  2012-03-23T12:42:03+                   22
#  2012-03-23T12:42:04+                   12
#  2012-03-23T12:42:05+                   45
#  2012-03-23T12:42:06+                   37
#  2012-03-23T12:42:07+                   43
#  2012-03-23T12:42:08+                    5
#  2012-03-23T12:42:09+                   15
#  2012-03-23T12:42:10+                   16
#  2012-03-23T12:42:11+                    1
#  2012-03-23T12:42:12+                   28
#  2012-03-23T12:42:13+                   33
#  2012-03-23T12:42:14+                   16
#                   ...                  ...

# %% [markdown]
# ## Hierarchical Index support
#
# ### The MultiIndex class

# %%
multi_index = Daru::MultiIndex.from_tuples([
  [:a, :b, :c],
  [:a, :b, :d],
  [:a, :b, :p],
  [:a, :q, :p],
  [:b, :r, :f],
  [:c, :o, :t],
  [:c, :p, :w]
  ])
# Out:
# #<Daru::MultiIndex(7x3)>
#    a   b   c
#            d
#            p
#        q   p
#    b   r   f
#    c   o   t
#        p   w

# %% [markdown]
# #### It allows you create and query hierarchically named data

# %%
vec = Daru::Vector.new([1,2,3]*2 << 66, index: multi_index)
# Out:
# #<Daru::Vector(7)>
#    a   b   c   1
#            d   2
#            p   3
#        q   p   1
#    b   r   f   2
#    c   o   t   3
#        p   w  66

# %% [markdown]
# #### You can select data by specifying the level of nesting in the #[] method.

# %%
vec[:a, :b]
# Out:
# #<Daru::Vector(3)>
#    c   1
#    d   2
#    p   3

# %%
vec[:a]
# Out:
# #<Daru::Vector(4)>
#    b   c   1
#        d   2
#        p   3
#    q   p   1

# %%
vec[:c, :o, :t]
# Out:
# 3

# %% [markdown]
# ## Visualization
#
# ### Simple Visualization with interactive graphs
#
# **Plotting a simple scatter plot from a DataFrame. Nyaplot integration provides interactivity.**
#
# **DataFrame denoting Ice Cream sales of a particular food chain in a city according to the maximum recorded temperature in that city. It also lists the staff strength present in each city.**

# %%
df = Daru::DataFrame.new({
  :temperature => [30.4, 23.5, 44.5, 20.3, 34, 24, 31.45, 28.34, 37, 24],
  :sales       => [350, 150, 500, 200, 480, 250, 330, 400, 420, 560],
  :city        => ['Pune', 'Delhi']*5,
  :staff       => [15,20]*5
})
df
# Out:
# #<Daru::DataFrame(10x4)>
#                   city      sales      staff temperatur
#           0       Pune        350         15       30.4
#           1      Delhi        150         20       23.5
#           2       Pune        500         15       44.5
#           3      Delhi        200         20       20.3
#           4       Pune        480         15         34
#           5      Delhi        250         20         24
#           6       Pune        330         15      31.45
#           7      Delhi        400         20      28.34
#           8       Pune        420         15         37
#           9      Delhi        560         20         24

# %% [markdown]
# **The plot below is between Temperature in the city and the sales of ice cream.**

# %%
df.plot(type: :scatter, x: :temperature, y: :sales) do |plot, diagram|
  plot.x_label "Temperature"
  plot.y_label "Sales"
  plot.yrange [100, 600]
  plot.xrange [15, 50]
  diagram.tooltip_contents([:city, :staff])
  # Set the color scheme for this diagram.
  diagram.color(Nyaplot::Colors.qual) 
  # Change color of each point WRT to the city that it belongs to.
  diagram.fill_by(:city)
  # Shape each point WRT to the city that it belongs to.
  diagram.shape_by(:city) 
end
# Out:
# #<Nyaplot::Frame:0x9d50db4 @properties={:panes=>[#<Nyaplot::Plot:0x9d5a120 @properties={:diagrams=>[#<Nyaplot::Diagram:0x9d51534 @properties={:type=>:scatter, :options=>{:x=>:temperature, :y=>:sales, :tooltip_contents=>[:city, :staff], :color=>#<Nyaplot::Color:0x9d50e40 @source=["rgb(251,180,174)", "rgb(179,205,227)", "rgb(204,235,197)", "rgb(222,203,228)", "rgb(254,217,166)", "rgb(255,255,204)", "rgb(229,216,189)", "rgb(253,218,236)", "rgb(242,242,242)"]>, :fill_by=>:city, :shape_by=>:city}, :data=>"0ee274ca-d048-43eb-a7cd-d8528e1538b3"}, @xrange=[20.3, 44.5], @yrange=[150, 560]>], :options=>{:x_label=>"Temperature", :y_label=>"Sales", :yrange=>[100, 600], :xrange=>[15, 50], :zoom=>true, :width=>700}}>], :data=>{"0ee274ca-d048-43eb-a7cd-d8528e1538b3"=>#<Nyaplot::DataFrame:0x9d51944 @name="0ee274ca-d048-43eb-a7cd-d8528e1538b3", @rows=[{:city=>"Pune", :sales=>350, :staff=>15, :temperature=>30.4}, {:city=>"Delhi", :sales=>150, :staff=>20, :temperature=>23.5}, {:city=>"Pune", :sales=>500, :staff=>15, :temperature=>44.5}, {:city=>"Delhi", :sales=>200, :staff=>20, :temperature=>20.3}, {:city=>"Pune", :sales=>480, :staff=>15, :temperature=>34}, {:city=>"Delhi", :sales=>250, :staff=>20, :temperature=>24}, {:city=>"Pune", :sales=>330, :staff=>15, :temperature=>31.45}, {:city=>"Delhi", :sales=>400, :staff=>20, :temperature=>28.34}, {:city=>"Pune", :sales=>420, :staff=>15, :temperature=>37}, {:city=>"Delhi", :sales=>560, :staff=>20, :temperature=>24}]>}, :extension=>[]}>

# %% [markdown]
# ### Use with GNU plot
#
# #### Plotting a time series with it's rolling mean
#
# **Init a random number generator for creating a normal distribution **

# %%
rng = Distribution::Normal.rng
# Out:
# #<Proc:0x9c26b78@/home/sameer/.rvm/gems/ruby-2.2.1/gems/distribution-0.7.3/lib/distribution/normal/gsl.rb:8 (lambda)>

# %%
index  = Daru::DateTimeIndex.date_range(:start => '2012-4-2', :periods => 1000)
vector = Daru::Vector.new(1000.times.map {rng.call}, index: index)
vector = vector.cumsum
rolling_mean = vector.rolling_mean 60

GnuplotRB::Plot.new(
  [vector      , with: 'lines', title: 'Vector'], 
  [rolling_mean, with: 'lines', title: 'Rolling Mean'],
  xlabel: 'Time', ylabel: 'Value'
)
# Out:
# #<GnuplotRB::Plot:0x9bf6824 @options=Hamster::Hash[:xdata => "time", :timefmt => "%Y-%m-%dT%H:%M:%S", :format_x => "%d\\n%b\\n%Y", :xlabel => "Time", :ylabel => "Value"], @datasets=Hamster::Vector[#<GnuplotRB::Dataset:0x9bf65f4 @type=:datablock, @data=#<GnuplotRB::Datablock:0x9bf63d8 @stored_in_file=false, @data="2012-04-02T00:00:00+00:00 -1.0589706068499247\n2012-04-03T00:00:00+00:00 0.0434320030889368\n2012-04-04T00:00:00+00:00 1.4255978767307196\n2012-04-05T00:00:00+00:00 0.6428128703164497\n2012-04-06T00:00:00+00:00 -0.3927771276527636\n2012-04-07T00:00:00+00:00 -0.2746320633086043\n2012-04-08T00:00:00+00:00 -0.01134537903094096\n2012-04-09T00:00:00+00:00 -1.4663013814638148\n2012-04-10T00:00:00+00:00 -0.16915835837975646\n2012-04-11T00:00:00+00:00 -1.7429816814315207\n2012-04-12T00:00:00+00:00 -2.2023193966862364\n2012-04-13T00:00:00+00:00 -1.899385637198792\n2012-04-14T00:00:00+00:00 -1.7222894683124645\n2012-04-15T00:00:00+00:00 -2.421132955595012\n2012-04-16T00:00:00+00:00 -2.7129687330048413\n2012-04-17T00:00:00+00:00 -3.9052122740154855\n2012-04-18T00:00:00+00:00 -3.9156088708458237\n2012-04-19T00:00:00+00:00 -5.26637354429632\n2012-04-20T00:00:00+00:00 -4.80639410305816\n2012-04-21T00:00:00+00:00 -5.134029726801259\n2012-04-22T00:00:00+00:00 -4.075852104643062\n2012-04-23T00:00:00+00:00 -3.8686202509376524\n2012-04-24T00:00:00+00:00 -4.482253996116291\n2012-04-25T00:00:00+00:00 -5.763820352373516\n2012-04-26T00:00:00+00:00 -4.775884443426374\n2012-04-27T00:00:00+00:00 -4.863125174605386\n2012-04-28T00:00:00+00:00 -4.922787490701109\n2012-04-29T00:00:00+00:00 -4.4854521775776774\n2012-04-30T00:00:00+00:00 -4.665637954384946\n2012-05-01T00:00:00+00:00 -5.504145122770209\n2012-05-02T00:00:00+00:00 -5.320441959556682\n2012-05-03T00:00:00+00:00 -6.480899474104238\n2012-05-04T00:00:00+00:00 -5.6972503625930715\n2012-05-05T00:00:00+00:00 -7.716399781368741\n2012-05-06T00:00:00+00:00 -7.201122123647709\n2012-05-07T00:00:00+00:00 -6.33734588258994\n2012-05-08T00:00:00+00:00 -5.529729591131984\n2012-05-09T00:00:00+00:00 -6.845837164435769\n2012-05-10T00:00:00+00:00 -8.656488428537598\n2012-05-11T00:00:00+00:00 -7.725279769226658\n2012-05-12T00:00:00+00:00 -8.673074551356127\n2012-05-13T00:00:00+00:00 -8.052162715473187\n2012-05-14T00:00:00+00:00 -7.327754157172319\n2012-05-15T00:00:00+00:00 -8.436822203422151\n2012-05-16T00:00:00+00:00 -9.595511995160868\n2012-05-17T00:00:00+00:00 -9.915901983437642\n2012-05-18T00:00:00+00:00 -9.574244211060812\n2012-05-19T00:00:00+00:00 -9.133058197841732\n2012-05-20T00:00:00+00:00 -10.374446941755883\n2012-05-21T00:00:00+00:00 -10.234305546740803\n2012-05-22T00:00:00+00:00 -9.94900779192308\n2012-05-23T00:00:00+00:00 -10.37051510547685\n2012-05-24T00:00:00+00:00 -11.223689656775996\n2012-05-25T00:00:00+00:00 -11.080699093464396\n2012-05-26T00:00:00+00:00 -11.45144567420161\n2012-05-27T00:00:00+00:00 -11.34170436550745\n2012-05-28T00:00:00+00:00 -10.94716549261727\n2012-05-29T00:00:00+00:00 -12.351784387304512\n2012-05-30T00:00:00+00:00 -14.399888229871886\n2012-05-31T00:00:00+00:00 -14.110856704537222\n2012-06-01T00:00:00+00:00 -13.210370326864984\n2012-06-02T00:00:00+00:00 -13.514562161519095\n2012-06-03T00:00:00+00:00 -14.560500202160275\n2012-06-04T00:00:00+00:00 -13.148018342718075\n2012-06-05T00:00:00+00:00 -14.248833955995805\n2012-06-06T00:00:00+00:00 -15.182814167825306\n2012-06-07T00:00:00+00:00 -14.156407391268935\n2012-06-08T00:00:00+00:00 -13.822556914789871\n2012-06-09T00:00:00+00:00 -15.00140092043064\n2012-06-10T00:00:00+00:00 -13.546988997790956\n2012-06-11T00:00:00+00:00 -14.970826998623927\n2012-06-12T00:00:00+00:00 -14.53689067495708\n2012-06-13T00:00:00+00:00 -14.141568130585894\n2012-06-14T00:00:00+00:00 -14.639568697378031\n2012-06-15T00:00:00+00:00 -15.386703616775911\n2012-06-16T00:00:00+00:00 -14.611509560810433\n2012-06-17T00:00:00+00:00 -13.29103329261099\n2012-06-18T00:00:00+00:00 -13.682333325567528\n2012-06-19T00:00:00+00:00 -13.252246408960398\n2012-06-20T00:0 ...

# %% [markdown]
# ## Arel-like syntax
#
# **Web devs will feel right at home!**
#
# **Fast and intuitive syntax for retreiving data with boolean indexing.**
#
# ### The 'where' clause

# %%
df = Daru::DataFrame.new({
  a: [1,2,3,4,5,6]*100,
  b: ['a','b','c','d','e','f']*100,
  c: [11,22,33,44,55,66]*100
}, index: (1..600).to_a.shuffle)
df
# Out:
# #<Daru::DataFrame(600x3)>
#        a   b   c
#  255   1   a  11
#  324   2   b  22
#  575   3   c  33
#  355   4   d  44
#  206   5   e  55
#   38   6   f  66
#  267   1   a  11
#  569   2   b  22
#  458   3   c  33
#   95   4   d  44
#  179   5   e  55
#  367   6   f  66
#  325   1   a  11
#  330   2   b  22
#  414   3   c  33
#  ... ... ... ...

# %% [markdown]
# **Compares with a bunch of scalar quantities and returns a DataFrame wherever they return *true***

# %%
df.where(df[:a].eq(2).or(df[:c].eq(55)))
# Out:
# #<Daru::DataFrame(200x3)>
#        a   b   c
#  324   2   b  22
#  206   5   e  55
#  569   2   b  22
#  179   5   e  55
#  330   2   b  22
#   51   5   e  55
#  226   2   b  22
#   69   5   e  55
#  194   2   b  22
#   34   5   e  55
#  143   2   b  22
#  465   5   e  55
#  299   2   b  22
#  412   5   e  55
#  284   2   b  22
#  ... ... ... ...
